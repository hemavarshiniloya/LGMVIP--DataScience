# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ntr = 7000
nts = 3000

train = pd.read_csv('/content/train.csv',nrows=ntr)

names=['msno','song_id','source_system_tab','source_screen_name',\
      'source_type','target']

test1 = pd.read_csv('/content/train.csv',names=names,skiprows=ntr,nrows=nts)

songs = pd.read_csv('/content/songs.csv')

members = pd.read_csv('/content/members.csv')

# %%
train
# Out:
#                                               msno  \
# 0     FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1     Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2     Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3     Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4     FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# ...                                            ...
# 6995  kOXcer+//oOLtOB6JLhxNqj/3YyTH2m+kWfvYTtMc7I=
# 6996  RdINwi/2oZyfF8FR5XiSONsD3acLPF31HJ67ZMd1Gt0=
# 6997  RdINwi/2oZyfF8FR5XiSONsD3acLPF31HJ67ZMd1Gt0=
# 6998  kOXcer+//oOLtOB6JLhxNqj/3YyTH2m+kWfvYTtMc7I=
# 6999  RdINwi/2oZyfF8FR5XiSONsD3acLPF31HJ67ZMd1Gt0=
#
#                                            song_id source_system_tab  \
# 0     BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=           explore
# 1     bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=        my library
# 2     JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=        my library
# 3     2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=        my library
# 4     3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=           explore
# ...                                            ...               ...
# 6995  kU2L9oE7z8H2bB+2/h0ZuRjvJ5t0QheJyggAB1fV6ac=            search
# 6996  M5jomDIbTepOkTFwYQ8CSAPObDTzPT93Uhc6+OMjtPk=        my library
# 6997  w47lM8vYQxHnTEdTUxbCF3+qJlOZy2T+WBPAGaaEmT8=        my library
# 6998  oU2T/lj1BsqWxNgh+xkmiBaPNYzNAoQj4zI1/mnjjiw=            search
# 6999  gpioqmDgSWfpkkCSQts5GMAGaM1TFH5zpVawYOjxIog=        my library
#
#         source_screen_name      source_type  target
# 0                  Explore  online-playlist       1
# 1      Local playlist more   local-playlist       1
# 2      Local playlist more   local-playlist       1
# 3      Local playlist more   local-playlist       1
# 4                  Explore  online-playlist       1
# ...                    ...              ...     ...
# 6995  Online playlist more  online-playlist       0
# 6996   Local playlist more    local-library       1
# 6997   Local playlist more    local-library       1
# 6998  Online playlist more  online-playlist       0
# 6999   Local playlist more    local-library       1
#
# [7000 rows x 6 columns]

# %%
songs
# Out:
#                                              song_id  song_length genre_ids  \
# 0       CXoTN1eb7AI+DntdU1vbcwGRV4SCIDxZu+YD8JP8r4E=       247640       465
# 1       o0kFgae9QtnYgRkVPqLJwa05zIhRlUjfF7O1tDw0ZDU=       197328       444
# 2       DwVvVurfpuz+XPuFvucclVQEyPqcpUkHR0ne1RQzPs0=       231781       465
# 3       dKMBWoZyScdxSkihKG+Vf47nc18N9q4m58+b4e7dSSE=       273554       465
# 4       W3bqWd3T+VeHFzHAUfARgW9AvVRaF4N5Yzm4Mr6Eo/o=       140329       726
# ...                                              ...          ...       ...
# 333489  30U2g58A9C5EoZ+NyynKUdqbA35FDywHd40FaQHHIH4=       290481       465
# 333490  VntYgs/w2cDTcxxT5DNqRqxood1Ivj1EhvspxOAbX48=       270837       465
# 333491  J10igfmpoPSscWpvE+nCt+IFu/hxNrWsftrnGfLAE8w=       397339      1609
# 333492  6/+rvRU6ZJU69KwMlxUwJaRjNxXACb1FKbus9fVA6XI=       195918       465
# 333493  g0s5e1WMr/ig6TwHF/UVrKAF6XFmNJmq4M+lxrHUXFI=       159764       921
#
#                artist_name                                        composer  \
# 0         張信哲 (Jeff Chang)                                              董貞
# 1                BLACKPINK              TEDDY|  FUTURE BOUNCE|  Bekuh BOOM
# 2             SUPER JUNIOR                                             NaN
# 3                    S.H.E                                             湯小康
# 4                     貴族精選                                     Traditional
# ...                    ...                                             ...
# 333489  張學友 (Jacky Cheung)                               Tian Shen Jiu Bao
# 333490               西內麻里亞                                           西内まりや
# 333491      Massive Attack  Sinead O'Connor| Neil Davidge| Robert Del Naja
# 333492     馬浚偉 (Steven Ma)                                             葉肇中
# 333493     Various Artists                                             NaN
#
#            lyricist  language
# 0               何啟弘         3
# 1             TEDDY        31
# 2               NaN        31
# 3               徐世珍         3
# 4       Traditional        52
# ...             ...       ...
# 333489          NaN        24
# 333490        西内まりや        17
# 333491          NaN        52
# 333492          陳詩慧        24
# 333493          NaN        31
#
# [333494 rows x 7 columns]

# %%
train.shape
# Out:
# (7000, 6)

# %%
train.describe()
# Out:
#             target
# count  7000.000000
# mean      0.783429
# std       0.411937
# min       0.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   msno                7000 non-null   object
#  1   song_id             7000 non-null   object
#  2   source_system_tab   6986 non-null   object
#  3   source_screen_name  6815 non-null   object
#  4   source_type         6986 non-null   object
#  5   target              7000 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 328.2+ KB

# %%
songs.shape
# Out:
# (333494, 7)

# %%
songs.describe()
# Out:
#         song_length       language
# count  3.334940e+05  333494.000000
# mean   2.477476e+05      28.566022
# std    1.443380e+05      23.723528
# min    1.253000e+03      -1.000000
# 25%    1.956310e+05       3.000000
# 50%    2.321060e+05      31.000000
# 75%    2.745060e+05      52.000000
# max    9.146340e+06      59.000000

# %%
songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333494 entries, 0 to 333493
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   song_id      333494 non-null  object
#  1   song_length  333494 non-null  int64
#  2   genre_ids    325301 non-null  object
#  3   artist_name  333494 non-null  object
#  4   composer     188169 non-null  object
#  5   lyricist     77492 non-null   object
#  6   language     333494 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 17.8+ MB

# %%
members
# Out:
#                                                msno  city  bd gender  \
# 0      XQxgAYj3klVKjR3oxPPXYYFp4soD4TuBghkhMTD4oTw=     1   0    NaN
# 1      UizsfmJb9mV54qE9hCYyU07Va97c0lCRLEQX3ae+ztM=     1   0    NaN
# 2      D8nEhsIOBSoE6VthTaqDX8U6lqjJ7dLdr72mOyLya2A=     1   0    NaN
# 3      mCuD+tZ1hERA/o5GPqk38e041J8ZsBaLcu7nGoIIvhI=     1   0    NaN
# 4      q4HRBfVSssAFS9iRfxWrohxuk9kCYMKjHOEagUMV6rQ=     1   0    NaN
# ...                                             ...   ...  ..    ...
# 34398  Wwd/cudKVuLJ3txRVxlg2Zaeliu+LRUfiBmfrnxhRCY=     1   0    NaN
# 34399  g3JGnJX6Hg50lFbrNWfsHwCUmApIkiv2M8sXOaeXoIQ=     4  18   male
# 34400  IMaPMJuyN+ip9Vqi+z2XuXbFAP2kbHr+EvvCNkFfj+o=     1   0    NaN
# 34401  WAnCAJjUty9Stv8yKtV7ZC7PN+ilOy5FX3aIJgGPANM=     1   0    NaN
# 34402  xH8KpzKGeNNq6dOvy51c/8VzqOiGG+m6vabhsPSDHX4=     1   0    NaN
#
#        registered_via  registration_init_time  expiration_date
# 0                   7                20110820         20170920
# 1                   7                20150628         20170622
# 2                   4                20160411         20170712
# 3                   9                20150906         20150907
# 4                   4                20170126         20170613
# ...               ...                     ...              ...
# 34398               7                20131111         20170910
# 34399               3                20141024         20170518
# 34400               7                20130802         20170908
# 34401               7                20151020         20170920
# 34402               4                20160815         20160818
#
# [34403 rows x 7 columns]

# %%
members.shape
# Out:
# (34403, 7)

# %%
members.describe()
# Out:
#                city            bd  registered_via  registration_init_time  \
# count  34403.000000  34403.000000    34403.000000            3.440300e+04
# mean       5.371276     12.280935        5.953376            2.013994e+07
# std        6.243929     18.170251        2.287534            2.954015e+04
# min        1.000000    -43.000000        3.000000            2.004033e+07
# 25%        1.000000      0.000000        4.000000            2.012103e+07
# 50%        1.000000      0.000000        7.000000            2.015090e+07
# 75%       10.000000     25.000000        9.000000            2.016110e+07
# max       22.000000   1051.000000       16.000000            2.017023e+07
#
#        expiration_date
# count     3.440300e+04
# mean      2.016901e+07
# std       7.320925e+03
# min       1.970010e+07
# 25%       2.017020e+07
# 50%       2.017091e+07
# 75%       2.017093e+07
# max       2.020102e+07

# %%
members.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34403 entries, 0 to 34402
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   msno                    34403 non-null  object
#  1   city                    34403 non-null  int64
#  2   bd                      34403 non-null  int64
#  3   gender                  14501 non-null  object
#  4   registered_via          34403 non-null  int64
#  5   registration_init_time  34403 non-null  int64
#  6   expiration_date         34403 non-null  int64
# dtypes: int64(5), object(2)
# memory usage: 1.8+ MB

# %% [markdown]
# # DATA VISUALIZATION

# %%
#DATA VISUALIZATION
plt.figure(figsize=(12,6))
sns.countplot(x = train['source_system_tab'],hue=train['source_system_tab'])
# Out:
# <Axes: xlabel='source_system_tab', ylabel='count'>

# %%
plt.figure(figsize=(12,6))
sns.countplot(x = train['source_system_tab'],palette=['crimson','lime'],hue=train['target'])
# Out:
# <Axes: xlabel='source_system_tab', ylabel='count'>

# %%
sns.countplot(x = songs['language'],data =train,hue=songs['language'],orient='v')
# Out:
# <Axes: xlabel='language', ylabel='count'>

# %%
train = train.sample(frac=0.01)

# %%
train = pd.merge(train, songs, on='song_id', how='left')

# %%
train = pd.merge(train, members, on='msno', how='left')
train.shape
# Out:
# (70, 18)

# %%
np.mean(train.target)
# Out:
# 0.7428571428571429

# %%
for i in train.select_dtypes(include=['object']).columns:
    train[i][train[i].isnull()] = 'unknown'
    
train = train.fillna(value=0)
# Out:
# <ipython-input-64-8e33596651e9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[i][train[i].isnull()] = 'unknown'
# <ipython-input-64-8e33596651e9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[i][train[i].isnull()] = 'unknown'
# <ipython-input-64-8e33596651e9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[i][train[i].isnull()] = 'unknown'
# <ipython-input-64-8e33596651e9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[i][train[i].isnull()] = 'unknown'
# <ipython-input-64-8e33596651e9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[i][train[i].isnull()] = 'unknown'
# <ipython-input-64-8e33596651e9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[i][train[i].isnull()] = 'unknown'
# <ipython-input-64-8e33596651e9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[i][train[i].isnull()] = 'unknown'
# <ipython-input-64-8e33596651e9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[i][train[i].isnull()] = 'unknown'
# <ipython-input-64-8e33596651e9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[i][train[i].isnull()] = 'unknown'
# <ipython-input-64-8e33596651e9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[i][train[i].isnull()] = 'unknown'

# %%
train
# Out:
#                                             msno  \
# 0   6NinSPKZSleuNsKkENuk+hJbOXHXIJzNbmiI6gUqWrI=
# 1   OqnHbTtm5kM0q7b+e08J1O/vhiBvPvP8plh0rXiWy2M=
# 2   2iRwi6lYhoKAq95GVSPtHKp3VMW0Da41EVJzokTCtao=
# 3   gpd5qcKQgYl+EpMfLKTVS/RVjvthxy2aBEkA2dB39VA=
# 4   Hpcuh+v/zgxus8oh1kdDJSpGK/reBItu4xheSXqlSQg=
# ..                                           ...
# 65  a1d2KnoIq+/QdPaHUojFU7jnze1HDUxu5VFHJ2hti2w=
# 66  Qm1eiROMB1Y3gCR2D1m83M+DzNnYq+4hxT1wMpEfyCg=
# 67  VywQ78ARP7dH9DWx4LWIQZQk9MO8vrBnN6ytK3jtC44=
# 68  V2DY8rwmjGNdFjVuTCcJJpKFhRRypGsGBHaXvA8Gg6M=
# 69  nVOcYKBWLRYE8Rr+3MGRP9bQ6vP0y2pvr3J3vT2PFbY=
#
#                                          song_id source_system_tab  \
# 0   ZgZKC4G2ot9HtIQ8fxQAe7u+Z1sLZOtmRVLOyI8oDy8=        my library
# 1   bTlSHgnwaBMIKHseTFHanJ3Zr4x82ybrGkexpnxDhTY=          discover
# 2   +LztcJcPEEwsikk6+K5udm06XJQMzR4+lzavKLUyE0k=        my library
# 3   c6aOoe8XxkkoRkLOrDQbWTJP+kfJbr2bKHoafI/57uU=          discover
# 4   S9Ceoq7vRyE9wVvIyi8dWYZ+9bN3W/hP8i6nFTM8y70=        my library
# ..                                           ...               ...
# 65  154PbkP+rK60c/4i3zQukIdp2EUYh9exeyhaBXxJVGc=        my library
# 66  zx4aCmk+b/uPmvESsG8ekvi7qWmifSPNMXg1i8wyG8Q=        my library
# 67  1UHqpOyecqH+8NytyogNdQz/2zUDpmHzUF5lgH1gvyw=        my library
# 68  AcKjv7ba2x28Mm4nq4XM9QazWFLqyFn9S3L1dP14YD8=        my library
# 69  C9+87S3Nvh5V+Y9jYvaKIspw9RzEyi+KuqmuQwtbhKI=       listen with
#
#       source_screen_name      source_type  target  song_length genre_ids  \
# 0    Local playlist more    local-library       1     256000.0       465
# 1   Online playlist more  online-playlist       1     294086.0       458
# 2    Local playlist more    local-library       1     208492.0      1609
# 3   Online playlist more  online-playlist       1     245527.0       458
# 4    Local playlist more   local-playlist       1     263314.0       458
# ..                   ...              ...     ...          ...       ...
# 65   Local playlist more   local-playlist       1     221889.0      1609
# 66   Local playlist more    local-library       1     264150.0       458
# 67   Local playlist more   local-playlist       1          0.0   unknown
# 68   Local playlist more    local-library       1     242834.0       458
# 69   Others profile more      listen-with       0     308140.0       465
#
#          artist_name                                           composer  \
# 0    陳芳語 (Kimberley)                                     Skot Suyama 陶山
# 1           Eric 周興哲                                          Eric Chou
# 2   The Chainsmokers         Andrew Taggart| Emily Warren| Scott Harris
# 3          張藝興 (LAY)  LAY / Lim| Kwang Wook / Ryan Kim / Anthony Lee...
# 4     周杰倫 (Jay Chou)                                                周杰倫
# ..               ...                                                ...
# 65          Vicetone                                            unknown
# 66      艾怡良 (Eve Ai)                                 Jun-Wei Zhang-Jian
# 67           unknown                                            unknown
# 68    周杰倫 (Jay Chou)                                                周杰倫
# 69    孫子涵 (Niko Sun)                                                孫子涵
#
#                                       lyricist  language  city  bd   gender  \
# 0                                   JPM廖允杰/左光平       3.0     1   0  unknown
# 1                         Eric Chou| Yi-Wei Wu       3.0     5  32   female
# 2   Andrew Taggart| Emily Warren| Scott Harris      52.0    14  20   female
# 3                   Chinese Lyrics by LAY / CC       3.0     4  32   female
# 4                                          周杰倫       3.0    14  31   female
# ..                                         ...       ...   ...  ..      ...
# 65                                     unknown      -1.0     1   0  unknown
# 66                  Eve Ai| Jun-Wei Zhang-Jian       3.0    13  24   female
# 67                                     unknown       0.0    15  24     male
# 68                                         周杰倫       3.0     1   0  unknown
# 69                                         孫子涵       3.0     6  20   female
#
#     registered_via  registration_init_time  expiration_date
# 0                7                20120629         20170930
# 1                3                20140711         20170730
# 2                9                20160227         20171122
# 3                9                20161006         20171005
# 4                3                20140309         20161229
# ..             ...                     ...              ...
# 65               7                20160422         20170921
# 66               9                20141216         20170621
# 67               9                20110219         20171016
# 68               7                20151014         20170913
# 69               7                20160321         20170930
#
# [70 rows x 18 columns]

# %%
train['registration_init_time'] = train['registration_init_time'].astype('category')
train['expiration_date'] = train['expiration_date'].astype('category')

# %%
for col in train.select_dtypes(include=['object']).columns:
    train[col] = train[col].astype('category')

# %%
for i in train.select_dtypes(include=['category']).columns:
    train[i] = train[i].cat.codes

# %%
from sklearn.model_selection import train_test_split

# %%
X_train = train.drop(['target'], axis = 1).values
y_train = train['target'].values

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train,test_size=0.3)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc= RandomForestClassifier(n_estimators=250)

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=250)

# %%
RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,criterion='gini', max_depth=None, max_features='auto',
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, 
                       min_samples_leaf=1, min_samples_split=2,
                       min_weight_fraction_leaf=0.0, n_estimators=250,
                       n_jobs=None, oob_score=False, random_state=None, verbose=0, warm_start=False)
# Out:
# RandomForestClassifier(max_features='auto', n_estimators=250)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
rfc_pred = rfc.predict(X_test)
print(confusion_matrix(y_test,rfc_pred))
# Out:
# [[ 2  3]
#  [ 2 14]]

# %%
print(classification_report(y_test,rfc_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.40      0.44         5
#            1       0.82      0.88      0.85        16
#
#     accuracy                           0.76        21
#    macro avg       0.66      0.64      0.65        21
# weighted avg       0.75      0.76      0.75        21
